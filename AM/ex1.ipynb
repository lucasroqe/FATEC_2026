# %%
import numpy as np
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

mnist = fetch_openml('mnist_784', version=1, as_frame=False, parser='auto')
X, y = mnist['data'], mnist['target']
# Out:
# Carregando MNIST...

# %%
# ALVO BINÁRIO P N° 3
y = y.astype(np.uint8)
y_3 = (y == 3)

X_train, X_test, y_train, y_test = train_test_split(X, y_3, test_size=10000, random_state=42)

print(f'Conjunto de treino: {X_train.shape}')
print(f'Conjunto de teste: {X_test.shape}')
# Out:
# Conjunto de treino: (60000, 784)
# Conjunto de teste: (10000, 784)

# %%
sgd_clf = SGDClassifier(random_state=42)
sgd_clf.fit(X_train, y_train)
# Out:
# Modelo treinado!

# %%
y_pred = sgd_clf.predict(X_test)
cm = confusion_matrix(y_test, y_pred)

# MATRIZ
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Não é 3', 'É 3'])
disp.plot(cmap=plt.cm.Blues)
plt.title('Matriz de Confusão - Classificador do Dígito 3')
plt.show()
